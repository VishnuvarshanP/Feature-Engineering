# %% [markdown]
# ###Capturing NaN Values with a new feature
# It works well in data which is not missing completely at random

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('titanic.csv',usecols=['age','fare','survived'])

# %%
df.head()
# Out:
#    survived   age     fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df['age_nan']=np.where(df['age'].isnull(),1,0)

# %%
df.head()
# Out:
#    survived   age     fare  age_nan
# 0         0  22.0   7.2500        0
# 1         1  38.0  71.2833        0
# 2         1  26.0   7.9250        0
# 3         1  35.0  53.1000        0
# 4         0  35.0   8.0500        0

# %%
df['age'].median()
# Out:
# 28.0

# %%
df['age'].fillna(df['age'].median(),inplace=True)

# %%
df.head(30) #age_nan shows that the age values has something(changed or not)
# Out:
#     survived   age      fare  age_nan
# 0          0  22.0    7.2500        0
# 1          1  38.0   71.2833        0
# 2          1  26.0    7.9250        0
# 3          1  35.0   53.1000        0
# 4          0  35.0    8.0500        0
# 5          0  28.0    8.4583        1
# 6          0  54.0   51.8625        0
# 7          0   2.0   21.0750        0
# 8          1  27.0   11.1333        0
# 9          1  14.0   30.0708        0
# 10         1   4.0   16.7000        0
# 11         1  58.0   26.5500        0
# 12         0  20.0    8.0500        0
# 13         0  39.0   31.2750        0
# 14         0  14.0    7.8542        0
# 15         1  55.0   16.0000        0
# 16         0   2.0   29.1250        0
# 17         1  28.0   13.0000        1
# 18         0  31.0   18.0000        0
# 19         1  28.0    7.2250        1
# 20         0  35.0   26.0000        0
# 21         1  34.0   13.0000        0
# 22         1  15.0    8.0292        0
# 23         1  28.0   35.5000        0
# 24         0   8.0   21.0750        0
# 25         1  38.0   31.3875        0
# 26         0  28.0    7.2250        1
# 27         0  19.0  263.0000        0
# 28         1  28.0    7.8792        1
# 29         0  28.0    7.8958        1

# %% [markdown]
# ###Advantages
# 1. Easy to implement
# 2. Captures the importance of missing values
#
# ###Disadvantages
# 1. Creating additional features(Curse of dimensionality)
